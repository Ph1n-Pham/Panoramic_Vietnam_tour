# %% [markdown]
# # DA 350
# # Paronamic Tour of Vietnam
# # Phineas Pham & Hung Tran
# ## May 2023

# %%
#import libraries
# !pip install gurobipy
import pandas as pd
import gurobipy as gp
from gurobipy import *
from datetime import date
import gurobipy as GRB
#Import packages
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import GRB
import geopy.distance
import folium
from itertools import combinations, permutations
import itertools
import math
from geopy.distance import great_circle

# %%
# Create an environment with your WLS license
# key values left blank
params = {
"WLSACCESSID": '',
"WLSSECRET": ,
"LICENSEID": ,
}
env = gp.Env(params=params)

# Create the model within the Gurobi environment
model = gp.Model(env=env)

# %% [markdown]
# ## Data Preprocessing:

# %% [markdown]
# #### Input data:

# %%
df_location = pd.read_csv('/content/location.xlsx - Sheet1.csv')
df_location_noindex = df_location
df_location = df_location.set_index('Tourist Attraction')
df_location
# Out:
#                                       City   Region  Star Rating   Latitude  \
# Tourist Attraction
# Hoan Kiem Lake                       Hanoi    North          4.5  21.027846
# Long Bien Bridge                     Hanoi    North          4.0  21.044483
# Ha Long Bay                     Quang Ninh    North          4.5  20.971205
# Hoi An Ancient Town              Quang Nam  Central          4.5  15.880301
# Notre Dame Square         Ho Chi Minh City    South          4.0  10.779965
# Cu Chi Tunnel             Ho Chi Minh City    South          4.5  11.028019
# Thap Tram Huong                  Nha Trang  Central          3.5  12.240540
# Dragon Bridge                      Da Nang  Central          4.0  16.061336
# Cai Rang Floating Market           Can Tho    South          4.0  10.005237
# Vung Tau Lighthouse        Ba Ria_Vung Tau    South          4.0  10.334301
# Fansipan Mountain                     Sapa    North          4.5  22.306532
# Hue Imperial City                      Hue  Central          4.5  16.469350
#
#                            Longitude
# Tourist Attraction
# Hoan Kiem Lake            105.852278
# Long Bien Bridge          105.860837
# Ha Long Bay               107.049051
# Hoi An Ancient Town       108.338008
# Notre Dame Square         106.699105
# Cu Chi Tunnel             106.512466
# Thap Tram Huong           109.196901
# Dragon Bridge             108.227517
# Cai Rang Floating Market  105.745939
# Vung Tau Lighthouse       107.077675
# Fansipan Mountain         103.774733
# Hue Imperial City         107.578054

# %%
df_location.loc['Hoan Kiem Lake']['Star Rating']  # == 4.5
# Out:
# 4.5

# %% [markdown]
# #### initiate attraction map:

# %%
map_museum = folium.Map(location=[16,110],
                 zoom_start= 5.5,
                 control_scale=True)

for i,row in df_location_noindex.iterrows():
    #if i != 1:
    iframe = folium.IFrame('Attraction Name:' + str(row["Tourist Attraction"]))

    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=300, max_width=300)

    #Add each row to the map
    folium.Marker(location=[row['Latitude'],row['Longitude']],
                popup = popup, c=row['Tourist Attraction']).add_to(map_museum)

folium.Marker(location=[df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == 'Notre Dame Square', "Latitude"].iloc[0],
                        df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == "Notre Dame Square", "Longitude"].iloc[0]],
              icon=folium.Icon(color='red', icon='pushpin')).add_to(map_museum)

map_museum
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c92c5987a28cc56511ded858c48afc18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c92c5987a28cc56511ded858c48afc18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c92c5987a28cc56511ded858c48afc18 = L.map(
#                 &quot;map_c92c5987a28cc56511ded858c48afc18&quot;,
#                 {
#                     center: [16.0, 110.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c92c5987a28cc56511ded858c48afc18);
#
#
#
#
#
#             var tile_layer_102a8929162228439191892527d632f0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c92c5987a28cc56511ded858c48afc18);
#
#
#             var marker_3af3bed5bb97308752d6bf57b56ac8fe = L.marker(
#                 [21.02784567, 105.8522779],
#                 {&quot;c&quot;: &quot;Hoan Kiem Lake&quot;}
#             ).addTo(map_c92c5987a28cc56511ded858c48afc18);
#
#
#         var popup_eabd2bf30c5026485a52500cc337d8d8 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_95c4584739d6366cf9490a49ea3a29f1 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SG9hbiBLaWVtIExha2U=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_eabd2bf30c5026485a52500cc337d8d8.setContent(i_frame_95c4584739d6366cf9490a49ea3a29f1);
#
#
#
#         marker_3af3bed5bb97308752d6bf57b56ac8fe.bindPopup(popup_eabd2bf30c5026485a52500cc337d8d8)
#         ;
#
#
#
#
#             var marker_c6ca1ab116a4b5f6b0e4720345df5bc8 = L.marker(
#                 [21.04448346, 105.860837],
#                 {&quot;c&quot;: &quot;Long Bien Bridge&quot;}
#             ).addTo(map_c92c5987a28cc56511ded858c48afc18);
#
#
#         var popup_acd1da16cfe02b80c378190c17a337b3 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_305af4624bffccd415d72980a2e63aaa = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6TG9uZyBCaWVuIEJyaWRnZQ==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_acd1da16cfe02b80c378190c17a337b3.setContent(i_frame_305af4624bffccd415d72980a2e63aaa);
#
#
#
#         marker_c6ca1ab116a4b5f6b0e4720345df5bc8.bindPopup(popup_acd1da16cfe02b80c378190c17a337b3)
#         ;
#
#
#
#
#             var marker_2290820219f072c3b52dffa7f9f3cf6c = L.marker(
#                 [20.9712055, 107.0490512],
#                 {&quot;c&quot;: &quot;Ha Long Bay&quot;}
#             ).addTo(map_c92c5987a28cc56511ded858c48afc18);
#
#
#         var popup_b9836e0c019e16ae6e36649f7acb9399 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_6b87a73e0a60851bc413a985c403f1a8 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SGEgTG9uZyBCYXk=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_b9836e0c019e16ae6e36649f7acb9399.setContent(i_frame_6b87a73e0a60851bc413a985c403f1a8);
#
#
#
#         marker_2290820219f072c3b52dffa7f9f3cf6c.bindPopup(popup_b9836e0c019e16ae6e36649f7acb9399)
#         ;
#
#
#
#
#             var marker_1da4f9e30de270756538a2a2b650e9f0 = L.marker(
#                 [15.88030077, 108.3380075],
#                 {&quot;c&quot;: &quot;Hoi An Ancient Town&quot;}
#             ).addTo(map_c92c5987a28cc56511ded858c48afc18);
#
#
#         var popup_1b3095e1300b299a0d619d291826491b = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_7eff7c00017bd7b30f8933f5f66f27fd = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SG9pIEFuIEFuY2llbnQgVG93bg==&quot; style=&quot;position:abs

# %% [markdown]
# ### Traveling Salesman Estimate Solution: (by Gurobi provider)
# Functions that will generate constraints to solve the TS problem

# %%
## Calculate shortest subtour on a route
def subtour(edges):
    nodes = set(i for e in edges for i in e)
    unvisited = list(nodes)
    cycle = list(nodes)
    while unvisited:  # true if list is non-empty
        thiscycle = []
        neighbors = unvisited
        while neighbors:
            current = neighbors[0]
            thiscycle.append(current)
            unvisited.remove(current)
            neighbors = [j for i, j in edges.select(current, '*') if j in unvisited]
        if len(thiscycle) <= len(cycle):
            cycle = thiscycle # New shortest subtour
    return cycle

## Subtour elimination constraint generator
def subtourelim(model, where):
    global subtour_iterations
    if where == GRB.Callback.MIPSOL:
        # make a list of edges selected in the solution
        vals = model.cbGetSolution(model._vars)
        selected = gp.tuplelist((i, j) for i, j in model._vars.keys()
            if vals[i, j] > 0.5)
        tour = subtour(selected)
        if len(tour) < len(selected): #len(selected) is total number of edges
            model.cbLazy(gp.quicksum(model._vars[i, j] for i, j in permutations(tour, 2)) <= len(tour)-1)

# %% [markdown]
# input cost and time dataframes, then store in dict_cost and dict_time:

# %%
df_cost = pd.read_csv('/content/cost_df - Sheet1.csv')
df_cost = df_cost.fillna(999) #make na values to 999 so that model will not pick unavailable options
df_cost
# Out:
#                    Departure              Arrival  Walking    Bus   Taxi  \
# 0             Hoan Kiem Lake     Long Bien Bridge        0  999.0    2.0
# 1             Hoan Kiem Lake          Ha Long Bay        0   20.0  115.0
# 2             Hoan Kiem Lake  Hoi An Ancient Town        0   34.0  999.0
# 3             Hoan Kiem Lake    Notre Dame Square        0   55.0  999.0
# 4             Hoan Kiem Lake        Cu Chi Tunnel        0   94.0  999.0
# ..                       ...                  ...      ...    ...    ...
# 61  Cai Rang Floating Market    Fansipan Mountain        0   81.0  999.0
# 62  Cai Rang Floating Market    Hue Imperial City        0   46.0  999.0
# 63       Vung Tau Lighthouse    Fansipan Mountain        0   82.0  999.0
# 64       Vung Tau Lighthouse    Hue Imperial City        0   28.0  999.0
# 65         Fansipan Mountain    Hue Imperial City        0   34.0  999.0
#
#     Train  Airplane
# 0   999.0     999.0
# 1   999.0     263.0
# 2    35.5      65.5
# 3    55.0     102.5
# 4    80.0     127.0
# ..    ...       ...
# 61   83.5     253.0
# 62   60.5     314.5
# 63   79.5     128.0
# 64   92.0     221.5
# 65   40.5     999.0
#
# [66 rows x 7 columns]

# %%
dict_cost = {}
for i in range(66):
  temp = []
  temp.append(df_cost.at[i, 'Walking'])
  temp.append(df_cost.at[i, 'Bus'])
  temp.append(df_cost.at[i, 'Taxi'])
  temp.append(df_cost.at[i, 'Train'])
  temp.append(df_cost.at[i, 'Airplane'])
  dict_cost[(df_cost.at[i, 'Departure'], df_cost.at[i, 'Arrival'])] = temp
  dict_cost[(df_cost.at[i, 'Arrival'], df_cost.at[i, 'Departure'])] = temp
#dict_cost

# %%
df_time = pd.read_csv('/content/time_df - Sheet1.csv')
df_time = df_time.fillna(999)  #make na values as 999 so that the model won't choose these options
df_time
# Out:
#                    Departure              Arrival  Walking     Bus     Taxi  \
# 0             Hoan Kiem Lake     Long Bien Bridge      0.5  999.00    0.067
# 1             Hoan Kiem Lake          Ha Long Bay    999.0    3.15    1.670
# 2             Hoan Kiem Lake  Hoi An Ancient Town    999.0   17.00  999.000
# 3             Hoan Kiem Lake    Notre Dame Square    999.0   35.85   32.550
# 4             Hoan Kiem Lake        Cu Chi Tunnel    999.0   35.60  999.000
# ..                       ...                  ...      ...     ...      ...
# 61  Cai Rang Floating Market    Fansipan Mountain    999.0   47.00  999.000
# 62  Cai Rang Floating Market    Hue Imperial City    999.0   28.60  999.000
# 63       Vung Tau Lighthouse    Fansipan Mountain    999.0   41.75  999.000
# 64       Vung Tau Lighthouse    Hue Imperial City    999.0   25.00  999.000
# 65         Fansipan Mountain    Hue Imperial City    999.0   18.90  999.000
#
#      Train  Airplane
# 0   999.00    999.00
# 1   999.00      2.75
# 2    17.00      4.24
# 3   999.00      4.40
# 4    32.55      4.33
# ..     ...       ...
# 61   44.60      6.45
# 62   24.50      5.30
# 63   42.80      9.80
# 64   20.30      5.40
# 65   21.90    999.00
#
# [66 rows x 7 columns]

# %%
dict_time = {}
for i in range(66):
  temp = []
  temp.append(df_time.at[i, 'Walking'])
  temp.append(df_time.at[i, 'Bus'])
  temp.append(df_time.at[i, 'Taxi'])
  temp.append(df_time.at[i, 'Train'])
  temp.append(df_time.at[i, 'Airplane'])
  dict_time[(df_time.at[i, 'Departure'], df_time.at[i, 'Arrival'])] = temp
  dict_time[(df_time.at[i, 'Arrival'], df_time.at[i, 'Departure'])] = temp
#dict_time

# %% [markdown]
# ## Optimal model:

# %%
time_per_place = 5
_Time = 100
_Cost = 400


mod = gp.Model("Paranomic Tour")
mod.Params.LogToConsole = 0
location = list(df_location.index)
n = len(df_cost.keys())  #number of pairs

#add binary variables
a = mod.addVars(dict_cost.keys(), vtype="B", name = "walk")
b = mod.addVars(dict_cost.keys(), vtype="B", name = "bus")
c = mod.addVars(dict_cost.keys(), vtype="B", name = "taxi")
d = mod.addVars(dict_cost.keys(), vtype="B", name = "train")
e = mod.addVars(dict_cost.keys(), vtype="B", name = "airplane")

y = mod.addVars(dict_cost.keys(), vtype="B", name = "pathExist")
x = mod.addVars(location, vtype="B") #if visit

# Objective
mod.setObjective(gp.quicksum(df_location.loc[i]['Star Rating'] * x[i] for i in location), GRB.MAXIMIZE)

# Constraints
start = 'Hoan Kiem Lake'

# Ensure that all locations are visited once
# for i in location:
#     #must leave i once
#     mod.addConstr(gp.quicksum(y[i, j] for j in location if j != i) == 1)
#     #must arrive i once
#     mod.addConstr(gp.quicksum(y[j, i] for j in location if j != i) == 1)


# CONSTRAINTS
for i in location:
    for j in location:
        if i != j:

            mod.addConstr(y[i,j] + y[j,i] <= 1)
            # choose only 1 transportation
            mod.addConstr(a[i, j] + b[i, j] + c[i, j] + d[i, j] + e[i, j] <= 1)
            # Ensure that each trip goes in one direction only
            mod.addConstr(y[i,j] + y[j,i] <= x[j])
            # y = a+b+c+d+e constraint
            mod.addConstr(y[i,j] == (a[i,j]+b[i,j]+c[i,j]+d[i,j]+e[i,j]))
            # one transportation btwn 2 locations
            mod.addConstr(y[i,j] <= 1)
            mod.addConstr(a[i,j]+b[i,j]+c[i,j]+d[i,j]+e[i,j] <= 1)

for i in location:
    if i != start:
        # x constraint
        mod.addConstr(gp.quicksum(y[i, j] for j in location if j != i) == x[i])
        mod.addConstr(gp.quicksum(y[j, i] for j in location if j != i) == x[i])
        mod.addConstr(gp.quicksum(y[i, j] for j in location if j != i) <= 1)
        mod.addConstr(gp.quicksum(y[j, i] for j in location if j != i) <= 1)

        mod.addConstr(gp.quicksum(y[i, j] for j in location if j != i) == gp.quicksum(y[j, i] for j in location if j != i))

#sum go to = leave
#mod.addConstr()

#TIME constraint
mod.addQConstr(gp.quicksum(a[i,j]*dict_time[i,j][0] + b[i,j]*dict_time[i,j][1] + c[i,j]*dict_time[i,j][2] + d[i,j]*dict_time[i,j][3] + e[i,j]*dict_time[i,j][4] for (i,j) in dict_cost.keys()) + gp.quicksum(time_per_place*x[j] for j in location) <= _Time) #24 cuz each pair counts one location twice
#COST constraint
mod.addQConstr(gp.quicksum(a[i,j]*dict_cost[i,j][0] + b[i,j]*dict_cost[i,j][1] + c[i,j]*dict_cost[i,j][2] + d[i,j]*dict_cost[i,j][3] + e[i,j]*dict_cost[i,j][4] for (i,j) in dict_cost.keys()) <= _Cost)



# Optimize
mod._vars = y
# mod._vars = a
# mod._vars = b
# mod._vars = c
# mod._vars = d
# mod._vars = e
mod.Params.lazyConstraints = 1
mod.optimize(subtourelim)


if mod.Status == gp.GRB.INFEASIBLE:
    print("Model is infeasible")
elif mod.Status == gp.GRB.UNBOUNDED:
    print("Model is unbounded")
else:
    # Print results
    print("Objective Value:", mod.ObjVal)
    #print("Time taken:", round(mod.ObjVal * 60), "hours")
    print("----------------------------------")
    print("Optimal Route:")
    tour = ['Hoan Kiem Lake']
    # a_ls = ['Hoan Kiem Lake']
    # b_ls = ['Hoan Kiem Lake']
    # c_ls = ['Hoan Kiem Lake']
    # d_ls = ['Hoan Kiem Lake']
    # e_ls = ['Hoan Kiem Lake']
    current = 'Hoan Kiem Lake'
    count = 0
    while True:
        count  += 1
        for j in location:
            if j != current and y[current, j].X > 0.5:
                tour.append(j)
                current = j
                count += 1
                break

        if current == 'Hoan Kiem Lake':
            break
        if count == 100:
          break


    print(" -> ".join(tour))
    print("----------------------------------")
    print("# of locations", count)
    #vals = mod.getAttr('x', y)
    #selected = gp.tuplelist((i, j) for i, j in dict_cost.keys() if y[i, j] > 0.5)
    # for i in range(len(tour)-1):
    #     print(tour[i], "->", tour[i+1], ":", round(dict_cost[tour[i], tour[i+1]],2))
# Out:
# Objective Value: 47.0
# ----------------------------------
# Optimal Route:
# Hoan Kiem Lake -> Fansipan Mountain -> Long Bien Bridge -> Ha Long Bay -> Cu Chi Tunnel -> Cai Rang Floating Market -> Notre Dame Square -> Vung Tau Lighthouse -> Dragon Bridge -> Hoi An Ancient Town -> Hue Imperial City -> Hoan Kiem Lake
# ----------------------------------
# # of locations 22

# %%
map_museum = folium.Map(location=[16,110],
                 zoom_start= 5.5,
                 control_scale=True)

for i,row in df_location_noindex.iterrows():
    #if i != 1:
    iframe = folium.IFrame('Attraction Name:' + str(row["Tourist Attraction"]))

    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=300, max_width=300)

    #Add each row to the map
    folium.Marker(location=[row['Latitude'],row['Longitude']],
                popup = popup, c=row['Tourist Attraction']).add_to(map_museum)

folium.Marker(location=[df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == 'Hoan Kiem Lake', "Latitude"].iloc[0],
                        df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == 'Hoan Kiem Lake', "Longitude"].iloc[0]],
              icon=folium.Icon(color='red', icon='pushpin')).add_to(map_museum)

points = []
for i in tour:
    points.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i, "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i, "Longitude"].iloc[0]])
#add lines
for i in tour:
    folium.PolyLine(points, color="green", weight=2.5, opacity=1).add_to(map_museum)

total_cost = 0
total_time = 0

for i in a:
  if a[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="red", weight=2.5, opacity=1).add_to(map_museum)
    total_time += a[i].X*dict_time[i][0]
    total_cost += a[i].X*dict_cost[i][0]

for i in b:
  if b[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="yellow", weight=2.5, opacity=1).add_to(map_museum)
    total_time += b[i].X*dict_time[i][1]
    total_cost += b[i].X*dict_cost[i][1]

for i in c:
  if c[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="blue", weight=2.5, opacity=1).add_to(map_museum)
    total_time += c[i].X*dict_time[i][2]
    total_cost += c[i].X*dict_cost[i][2]

for i in d:
  if d[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="pink", weight=2.5, opacity=1).add_to(map_museum)
    total_time += d[i].X*dict_time[i][3]
    total_cost += d[i].X*dict_cost[i][3]

for i in e:
  if e[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="cyan", weight=2.5, opacity=1).add_to(map_museum)
    total_time += e[i].X*dict_time[i][4]
    total_cost += e[i].X*dict_cost[i][4]

map_museum
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d5886975c44269cd17afa26c29dce88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d5886975c44269cd17afa26c29dce88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d5886975c44269cd17afa26c29dce88 = L.map(
#                 &quot;map_5d5886975c44269cd17afa26c29dce88&quot;,
#                 {
#                     center: [16.0, 110.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5d5886975c44269cd17afa26c29dce88);
#
#
#
#
#
#             var tile_layer_b4e7d5d1238d1c4098c2c12b90d6ca27 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5d5886975c44269cd17afa26c29dce88);
#
#
#             var marker_16a59f660b9dc728db81e781e05241d3 = L.marker(
#                 [21.02784567, 105.8522779],
#                 {&quot;c&quot;: &quot;Hoan Kiem Lake&quot;}
#             ).addTo(map_5d5886975c44269cd17afa26c29dce88);
#
#
#         var popup_1bdfd24777466d6f2339990bc4b45b92 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_21410097f008842e0668051ff8ac1d87 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SG9hbiBLaWVtIExha2U=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_1bdfd24777466d6f2339990bc4b45b92.setContent(i_frame_21410097f008842e0668051ff8ac1d87);
#
#
#
#         marker_16a59f660b9dc728db81e781e05241d3.bindPopup(popup_1bdfd24777466d6f2339990bc4b45b92)
#         ;
#
#
#
#
#             var marker_338c0a3ddfb9171edaefc018117da713 = L.marker(
#                 [21.04448346, 105.860837],
#                 {&quot;c&quot;: &quot;Long Bien Bridge&quot;}
#             ).addTo(map_5d5886975c44269cd17afa26c29dce88);
#
#
#         var popup_8d4bfa5743a63c4419f1bdb84a9c8705 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_91ea6f8e0e0554a30dc095ad6313e326 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6TG9uZyBCaWVuIEJyaWRnZQ==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_8d4bfa5743a63c4419f1bdb84a9c8705.setContent(i_frame_91ea6f8e0e0554a30dc095ad6313e326);
#
#
#
#         marker_338c0a3ddfb9171edaefc018117da713.bindPopup(popup_8d4bfa5743a63c4419f1bdb84a9c8705)
#         ;
#
#
#
#
#             var marker_d76a5812793a9a5db668dc2b250a28fc = L.marker(
#                 [20.9712055, 107.0490512],
#                 {&quot;c&quot;: &quot;Ha Long Bay&quot;}
#             ).addTo(map_5d5886975c44269cd17afa26c29dce88);
#
#
#         var popup_b740bbb752110bbf308ef94198cd95c9 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_6b86672db7fd00ba4f5c7c3da84d5219 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SGEgTG9uZyBCYXk=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_b740bbb752110bbf308ef94198cd95c9.setContent(i_frame_6b86672db7fd00ba4f5c7c3da84d5219);
#
#
#
#         marker_d76a5812793a9a5db668dc2b250a28fc.bindPopup(popup_b740bbb752110bbf308ef94198cd95c9)
#         ;
#
#
#
#
#             var marker_c7a78b8df6519d7ada48a0d2feac47fb = L.marker(
#                 [15.88030077, 108.3380075],
#                 {&quot;c&quot;: &quot;Hoi An Ancient Town&quot;}
#             ).addTo(map_5d5886975c44269cd17afa26c29dce88);
#
#
#         var popup_7e6bd978a62f8ca0c12fa7b44453535e = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_5ef1c19bd8223d687d9699f73c86e53c = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SG9pIEFuIEFuY2llbnQgVG93bg==&quot; style=&quot;position:abs

# %% [markdown]
# ## All location Model:
# #### Add constraint to make model visit all inputted locations with relieved time and cost constraints

# %%
time_per_place = 5
_Time = 120
_Cost = 400


mod = gp.Model("Paranomic Tour")
mod.Params.LogToConsole = 0
location = list(df_location.index)
n = len(df_cost.keys())  #number of pairs

#add binary variables
a = mod.addVars(dict_cost.keys(), vtype="B", name = "walk")
b = mod.addVars(dict_cost.keys(), vtype="B", name = "bus")
c = mod.addVars(dict_cost.keys(), vtype="B", name = "taxi")
d = mod.addVars(dict_cost.keys(), vtype="B", name = "train")
e = mod.addVars(dict_cost.keys(), vtype="B", name = "airplane")

y = mod.addVars(dict_cost.keys(), vtype="B", name = "pathExist")
x = mod.addVars(location, vtype="B") #if visit

# Objective
mod.setObjective(gp.quicksum(df_location.loc[i]['Star Rating'] * x[i] for i in location), GRB.MAXIMIZE)

# Constraints
start = 'Hoan Kiem Lake'

#must leave start once
#mod.addConstr(gp.quicksum(a[start, j]+b[start, j]+c[start, j]+d[start, j]+e[start, j] for j in location if j != start) == 1)
#must arrive at Denison once
#mod.addConstr(gp.quicksum(a[j, start]+b[j, start]+c[j, start]+d[j, start]+e[j, start] for j in location if j != start) == 1)

# Ensure that all locations are visited once
for i in location:
    #must leave i once
    mod.addConstr(gp.quicksum(y[i, j] for j in location if j != i) == 1)
    #must arrive i once
    mod.addConstr(gp.quicksum(y[j, i] for j in location if j != i) == 1)


# CONSTRAINTS
for i in location:
    for j in location:
        if i != j:
            # one direction only
            # mod.addConstr(a[i, j] + a[j, i] <= 1)
            # mod.addConstr(b[i, j] + b[j, i] <= 1)
            # mod.addConstr(c[i, j] + c[j, i] <= 1)
            # mod.addConstr(d[i, j] + d[j, i] <= 1)
            # mod.addConstr(e[i, j] + e[j, i] <= 1)

            mod.addConstr(y[i,j] + y[j,i] <= 1)
            # choose only 1 transportation
            mod.addConstr(a[i, j] + b[i, j] + c[i, j] + d[i, j] + e[i, j] <= 1)
            # Ensure that each trip goes in one direction only
            mod.addConstr(y[i,j] + y[j,i] <= x[j])
            # y = a+b+c+d+e constraint
            mod.addConstr(y[i,j] == (a[i,j]+b[i,j]+c[i,j]+d[i,j]+e[i,j]))
            # one transportation btwn 2 locations
            mod.addConstr(y[i,j] <= 1)
            mod.addConstr(a[i,j]+b[i,j]+c[i,j]+d[i,j]+e[i,j] <= 1)

for i in location:
    if i != start:
        # x constraint
        mod.addConstr(gp.quicksum(y[i, j] for j in location if j != i) == x[i])
        mod.addConstr(gp.quicksum(y[j, i] for j in location if j != i) == x[i])
        mod.addConstr(gp.quicksum(y[i, j] for j in location if j != i) <= 1)
        mod.addConstr(gp.quicksum(y[j, i] for j in location if j != i) <= 1)

        mod.addConstr(gp.quicksum(y[i, j] for j in location if j != i) == gp.quicksum(y[j, i] for j in location if j != i))

#sum go to = leave
#mod.addConstr()

#TIME constraint
mod.addQConstr(gp.quicksum(a[i,j]*dict_time[i,j][0] + b[i,j]*dict_time[i,j][1] + c[i,j]*dict_time[i,j][2] + d[i,j]*dict_time[i,j][3] + e[i,j]*dict_time[i,j][4] for (i,j) in dict_cost.keys()) + gp.quicksum(time_per_place*x[j] for j in location) <= _Time) #24 cuz each pair counts one location twice
#COST constraint
mod.addQConstr(gp.quicksum(a[i,j]*dict_cost[i,j][0] + b[i,j]*dict_cost[i,j][1] + c[i,j]*dict_cost[i,j][2] + d[i,j]*dict_cost[i,j][3] + e[i,j]*dict_cost[i,j][4] for (i,j) in dict_cost.keys()) <= _Cost)



# Optimize
mod._vars = y
# mod._vars = a
# mod._vars = b
# mod._vars = c
# mod._vars = d
# mod._vars = e
mod.Params.lazyConstraints = 1
mod.optimize(subtourelim)


if mod.Status == gp.GRB.INFEASIBLE:
    print("Model is infeasible")
elif mod.Status == gp.GRB.UNBOUNDED:
    print("Model is unbounded")
else:
    # Print results
    print("Objective Value:", mod.ObjVal)
    #print("Time taken:", round(mod.ObjVal * 60), "hours")
    print("----------------------------------")
    print("Optimal Route:")
    tour = ['Hoan Kiem Lake']
    # a_ls = ['Hoan Kiem Lake']
    # b_ls = ['Hoan Kiem Lake']
    # c_ls = ['Hoan Kiem Lake']
    # d_ls = ['Hoan Kiem Lake']
    # e_ls = ['Hoan Kiem Lake']
    current = 'Hoan Kiem Lake'
    count = 0
    while True:
        count  += 1
        for j in location:
            if j != current and y[current, j].X > 0.5:
                tour.append(j)
                current = j
                count += 1
                break

        if current == 'Hoan Kiem Lake':
            break
        if count == 100:
          break


    print(" -> ".join(tour))
    print("----------------------------------")
    print("# of locations", count)
    #vals = mod.getAttr('x', y)
    #selected = gp.tuplelist((i, j) for i, j in dict_cost.keys() if y[i, j] > 0.5)
    # for i in range(len(tour)-1):
    #     print(tour[i], "->", tour[i+1], ":", round(dict_cost[tour[i], tour[i+1]],2))
# Out:
# Objective Value: 50.5
# ----------------------------------
# Optimal Route:
# Hoan Kiem Lake -> Long Bien Bridge -> Ha Long Bay -> Fansipan Mountain -> Thap Tram Huong -> Cai Rang Floating Market -> Cu Chi Tunnel -> Notre Dame Square -> Vung Tau Lighthouse -> Dragon Bridge -> Hoi An Ancient Town -> Hue Imperial City -> Hoan Kiem Lake
# ----------------------------------
# # of locations 24

# %%
map_museum = folium.Map(location=[16,110],
                 zoom_start= 5.5,
                 control_scale=True)

for i,row in df_location_noindex.iterrows():
    #if i != 1:
    iframe = folium.IFrame('Attraction Name:' + str(row["Tourist Attraction"]))

    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=300, max_width=300)

    #Add each row to the map
    folium.Marker(location=[row['Latitude'],row['Longitude']],
                popup = popup, c=row['Tourist Attraction']).add_to(map_museum)

folium.Marker(location=[df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == 'Hoan Kiem Lake', "Latitude"].iloc[0],
                        df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == 'Hoan Kiem Lake', "Longitude"].iloc[0]],
              icon=folium.Icon(color='red', icon='pushpin')).add_to(map_museum)

points = []
for i in tour:
    points.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i, "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i, "Longitude"].iloc[0]])
#add lines
for i in tour:
    folium.PolyLine(points, color="green", weight=2.5, opacity=1).add_to(map_museum)

total_cost = 0
total_time = 0

for i in a:
  if a[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="red", weight=2.5, opacity=1).add_to(map_museum)
    total_time += a[i].X*dict_time[i][0]
    total_cost += a[i].X*dict_cost[i][0]

for i in b:
  if b[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="yellow", weight=2.5, opacity=1).add_to(map_museum)
    total_time += b[i].X*dict_time[i][1]
    total_cost += b[i].X*dict_cost[i][1]

for i in c:
  if c[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="blue", weight=2.5, opacity=1).add_to(map_museum)
    total_time += c[i].X*dict_time[i][2]
    total_cost += c[i].X*dict_cost[i][2]

for i in d:
  if d[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="pink", weight=2.5, opacity=1).add_to(map_museum)
    total_time += d[i].X*dict_time[i][3]
    total_cost += d[i].X*dict_cost[i][3]

for i in e:
  if e[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="cyan", weight=2.5, opacity=1).add_to(map_museum)
    total_time += e[i].X*dict_time[i][4]
    total_cost += e[i].X*dict_cost[i][4]

map_museum
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29be60fe82c45bc542c6b289e03c7a70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29be60fe82c45bc542c6b289e03c7a70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29be60fe82c45bc542c6b289e03c7a70 = L.map(
#                 &quot;map_29be60fe82c45bc542c6b289e03c7a70&quot;,
#                 {
#                     center: [16.0, 110.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_29be60fe82c45bc542c6b289e03c7a70);
#
#
#
#
#
#             var tile_layer_6542781fcfa62a417972139c94fb7f0c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_29be60fe82c45bc542c6b289e03c7a70);
#
#
#             var marker_a16732643620b072bf9239554fb26a9e = L.marker(
#                 [21.02784567, 105.8522779],
#                 {&quot;c&quot;: &quot;Hoan Kiem Lake&quot;}
#             ).addTo(map_29be60fe82c45bc542c6b289e03c7a70);
#
#
#         var popup_4222f67e18b4f5a5bec09b85ef9789bd = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_2fd708c242162f5599ca248d2bba8da6 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SG9hbiBLaWVtIExha2U=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_4222f67e18b4f5a5bec09b85ef9789bd.setContent(i_frame_2fd708c242162f5599ca248d2bba8da6);
#
#
#
#         marker_a16732643620b072bf9239554fb26a9e.bindPopup(popup_4222f67e18b4f5a5bec09b85ef9789bd)
#         ;
#
#
#
#
#             var marker_de928f6f2bb364f6019802ec093884f1 = L.marker(
#                 [21.04448346, 105.860837],
#                 {&quot;c&quot;: &quot;Long Bien Bridge&quot;}
#             ).addTo(map_29be60fe82c45bc542c6b289e03c7a70);
#
#
#         var popup_ff0e3ffd0bed038aaaf6777d46112852 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_8ff11b19e97c844b59de5981ffcf3a45 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6TG9uZyBCaWVuIEJyaWRnZQ==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_ff0e3ffd0bed038aaaf6777d46112852.setContent(i_frame_8ff11b19e97c844b59de5981ffcf3a45);
#
#
#
#         marker_de928f6f2bb364f6019802ec093884f1.bindPopup(popup_ff0e3ffd0bed038aaaf6777d46112852)
#         ;
#
#
#
#
#             var marker_f666494cddc18226ce5a1e4ea5470b4b = L.marker(
#                 [20.9712055, 107.0490512],
#                 {&quot;c&quot;: &quot;Ha Long Bay&quot;}
#             ).addTo(map_29be60fe82c45bc542c6b289e03c7a70);
#
#
#         var popup_3985ad979c1c3d6d4b44e181d85684ce = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_d8f5e56e0cf85396f326a0704b975079 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SGEgTG9uZyBCYXk=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_3985ad979c1c3d6d4b44e181d85684ce.setContent(i_frame_d8f5e56e0cf85396f326a0704b975079);
#
#
#
#         marker_f666494cddc18226ce5a1e4ea5470b4b.bindPopup(popup_3985ad979c1c3d6d4b44e181d85684ce)
#         ;
#
#
#
#
#             var marker_bd6823ae5bb821f3b4895014c6516bc8 = L.marker(
#                 [15.88030077, 108.3380075],
#                 {&quot;c&quot;: &quot;Hoi An Ancient Town&quot;}
#             ).addTo(map_29be60fe82c45bc542c6b289e03c7a70);
#
#
#         var popup_978fe2eb3d387592440f6a7769a3c44a = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_dfc5d6da8824bce8403c3cc4d4d4472b = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SG9pIEFuIEFuY2llbnQgVG93bg==&quot; style=&quot;position:abs

# %%
print("Total time: ", total_time, "/ 100")
print("Total cost: ", total_cost, "/ 400")
# Out:
# Total time:  58.199999999999996 / 100
# Total cost:  392.5 / 400

# %% [markdown]
# ## Half Budget:

# %%
time_per_place = 5
_Time = 100
_Cost = 200


mod = gp.Model("Paranomic Tour")
mod.Params.LogToConsole = 0
location = list(df_location.index)
n = len(df_cost.keys())  #number of pairs

#add binary variables
a = mod.addVars(dict_cost.keys(), vtype="B", name = "walk")
b = mod.addVars(dict_cost.keys(), vtype="B", name = "bus")
c = mod.addVars(dict_cost.keys(), vtype="B", name = "taxi")
d = mod.addVars(dict_cost.keys(), vtype="B", name = "train")
e = mod.addVars(dict_cost.keys(), vtype="B", name = "airplane")

y = mod.addVars(dict_cost.keys(), vtype="B", name = "pathExist")
x = mod.addVars(location, vtype="B") #if visit

# Objective
mod.setObjective(gp.quicksum(df_location.loc[i]['Star Rating'] * x[i] for i in location), GRB.MAXIMIZE)

# Constraints
start = 'Hoan Kiem Lake'

# CONSTRAINTS
for i in location:
    for j in location:
        if i != j:
            mod.addConstr(y[i,j] + y[j,i] <= 1)
            # choose only 1 transportation
            mod.addConstr(a[i, j] + b[i, j] + c[i, j] + d[i, j] + e[i, j] <= 1)
            # Ensure that each trip goes in one direction only
            mod.addConstr(y[i,j] + y[j,i] <= x[j])
            # y = a+b+c+d+e constraint
            mod.addConstr(y[i,j] == (a[i,j]+b[i,j]+c[i,j]+d[i,j]+e[i,j]))
            # one transportation btwn 2 locations
            mod.addConstr(y[i,j] <= 1)
            mod.addConstr(a[i,j]+b[i,j]+c[i,j]+d[i,j]+e[i,j] <= 1)

for i in location:
    if i != start:
        # x constraint
        mod.addConstr(gp.quicksum(y[i, j] for j in location if j != i) == x[i])
        mod.addConstr(gp.quicksum(y[j, i] for j in location if j != i) == x[i])
        mod.addConstr(gp.quicksum(y[i, j] for j in location if j != i) <= 1)
        mod.addConstr(gp.quicksum(y[j, i] for j in location if j != i) <= 1)

        mod.addConstr(gp.quicksum(y[i, j] for j in location if j != i) == gp.quicksum(y[j, i] for j in location if j != i))

#sum go to = leave
#mod.addConstr()

#TIME constraint
mod.addQConstr(gp.quicksum(a[i,j]*dict_time[i,j][0] + b[i,j]*dict_time[i,j][1] + c[i,j]*dict_time[i,j][2] + d[i,j]*dict_time[i,j][3] + e[i,j]*dict_time[i,j][4] for (i,j) in dict_cost.keys()) + gp.quicksum(time_per_place*x[j] for j in location) <= _Time) #24 cuz each pair counts one location twice
#COST constraint
mod.addQConstr(gp.quicksum(a[i,j]*dict_cost[i,j][0] + b[i,j]*dict_cost[i,j][1] + c[i,j]*dict_cost[i,j][2] + d[i,j]*dict_cost[i,j][3] + e[i,j]*dict_cost[i,j][4] for (i,j) in dict_cost.keys()) <= _Cost)



# Optimize
mod._vars = y
# mod._vars = a
# mod._vars = b
# mod._vars = c
# mod._vars = d
# mod._vars = e
mod.Params.lazyConstraints = 1
mod.optimize(subtourelim)


if mod.Status == gp.GRB.INFEASIBLE:
    print("Model is infeasible")
elif mod.Status == gp.GRB.UNBOUNDED:
    print("Model is unbounded")
else:
    # Print results
    print("Objective Value:", mod.ObjVal)
    #print("Time taken:", round(mod.ObjVal * 60), "hours")
    print("----------------------------------")
    print("Optimal Route:")
    tour = ['Hoan Kiem Lake']
    # a_ls = ['Hoan Kiem Lake']
    # b_ls = ['Hoan Kiem Lake']
    # c_ls = ['Hoan Kiem Lake']
    # d_ls = ['Hoan Kiem Lake']
    # e_ls = ['Hoan Kiem Lake']
    current = 'Hoan Kiem Lake'
    count = 0
    while True:
        count  += 1
        for j in location:
            if j != current and y[current, j].X > 0.5:
                tour.append(j)
                current = j
                count += 1
                break

        if current == 'Hoan Kiem Lake':
            break
        if count == 100:
          break


    print(" -> ".join(tour))
    print("----------------------------------")
    print("# of locations", count)
    #vals = mod.getAttr('x', y)
    #selected = gp.tuplelist((i, j) for i, j in dict_cost.keys() if y[i, j] > 0.5)
    # for i in range(len(tour)-1):
    #     print(tour[i], "->", tour[i+1], ":", round(dict_cost[tour[i], tour[i+1]],2))
# Out:
# Objective Value: 37.5
# ----------------------------------
# Optimal Route:
# Hoan Kiem Lake -> Long Bien Bridge -> Thap Tram Huong -> Notre Dame Square -> Cu Chi Tunnel -> Vung Tau Lighthouse -> Dragon Bridge -> Hoi An Ancient Town -> Hue Imperial City -> Hoan Kiem Lake
# ----------------------------------
# # of locations 18

# %%
map_museum = folium.Map(location=[16,110],
                 zoom_start= 5.5,
                 control_scale=True)

for i,row in df_location_noindex.iterrows():
    #if i != 1:
    iframe = folium.IFrame('Attraction Name:' + str(row["Tourist Attraction"]))

    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=300, max_width=300)

    #Add each row to the map
    folium.Marker(location=[row['Latitude'],row['Longitude']],
                popup = popup, c=row['Tourist Attraction']).add_to(map_museum)

folium.Marker(location=[df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == 'Hoan Kiem Lake', "Latitude"].iloc[0],
                        df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == 'Hoan Kiem Lake', "Longitude"].iloc[0]],
              icon=folium.Icon(color='red', icon='pushpin')).add_to(map_museum)

points = []
for i in tour:
    points.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i, "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i, "Longitude"].iloc[0]])
#add lines
for i in tour:
    folium.PolyLine(points, color="green", weight=2.5, opacity=1).add_to(map_museum)

total_cost = 0
total_time = 0

for i in a:
  if a[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="red", weight=2.5, opacity=1).add_to(map_museum)
    total_time += a[i].X*dict_time[i][0]
    total_cost += a[i].X*dict_cost[i][0]

for i in b:
  if b[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="yellow", weight=2.5, opacity=1).add_to(map_museum)
    total_time += b[i].X*dict_time[i][1]
    total_cost += b[i].X*dict_cost[i][1]

for i in c:
  if c[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="blue", weight=2.5, opacity=1).add_to(map_museum)
    total_time += c[i].X*dict_time[i][2]
    total_cost += c[i].X*dict_cost[i][2]

for i in d:
  if d[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="pink", weight=2.5, opacity=1).add_to(map_museum)
    total_time += d[i].X*dict_time[i][3]
    total_cost += d[i].X*dict_cost[i][3]

for i in e:
  if e[i].X > 0:
    pt = []
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[0], "Longitude"].iloc[0]])
    pt.append([df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Latitude"].iloc[0],
                   df_location_noindex.loc[df_location_noindex["Tourist Attraction"] == i[1], "Longitude"].iloc[0]])
    folium.PolyLine(pt, color="cyan", weight=2.5, opacity=1).add_to(map_museum)
    total_time += e[i].X*dict_time[i][4]
    total_cost += e[i].X*dict_cost[i][4]

map_museum
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_686021c6b18ae445d56ac345d7f4187a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_686021c6b18ae445d56ac345d7f4187a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_686021c6b18ae445d56ac345d7f4187a = L.map(
#                 &quot;map_686021c6b18ae445d56ac345d7f4187a&quot;,
#                 {
#                     center: [16.0, 110.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_686021c6b18ae445d56ac345d7f4187a);
#
#
#
#
#
#             var tile_layer_317b97f3ae10439fccdb20ea160d5665 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_686021c6b18ae445d56ac345d7f4187a);
#
#
#             var marker_3f54202b77367c630096fef675eae9f1 = L.marker(
#                 [21.02784567, 105.8522779],
#                 {&quot;c&quot;: &quot;Hoan Kiem Lake&quot;}
#             ).addTo(map_686021c6b18ae445d56ac345d7f4187a);
#
#
#         var popup_6f32f84ddeff1ef4d46f109ca5c691af = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_628c568f400370669423a9021b4e1d8b = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SG9hbiBLaWVtIExha2U=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_6f32f84ddeff1ef4d46f109ca5c691af.setContent(i_frame_628c568f400370669423a9021b4e1d8b);
#
#
#
#         marker_3f54202b77367c630096fef675eae9f1.bindPopup(popup_6f32f84ddeff1ef4d46f109ca5c691af)
#         ;
#
#
#
#
#             var marker_4134b4c7831ca6117d9ead1ec429ac9d = L.marker(
#                 [21.04448346, 105.860837],
#                 {&quot;c&quot;: &quot;Long Bien Bridge&quot;}
#             ).addTo(map_686021c6b18ae445d56ac345d7f4187a);
#
#
#         var popup_2eaf929f556dc83dd1174ffb3f06010b = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_42cbca0664c6895a15ba49001fdb84c2 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6TG9uZyBCaWVuIEJyaWRnZQ==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_2eaf929f556dc83dd1174ffb3f06010b.setContent(i_frame_42cbca0664c6895a15ba49001fdb84c2);
#
#
#
#         marker_4134b4c7831ca6117d9ead1ec429ac9d.bindPopup(popup_2eaf929f556dc83dd1174ffb3f06010b)
#         ;
#
#
#
#
#             var marker_d31e75d6e8f4fc0694e7654062b4414e = L.marker(
#                 [20.9712055, 107.0490512],
#                 {&quot;c&quot;: &quot;Ha Long Bay&quot;}
#             ).addTo(map_686021c6b18ae445d56ac345d7f4187a);
#
#
#         var popup_71a5d5ee9b784d65b7b8ba33f6e01add = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_2586c6b1ad6c824a2221ae26de0e6cbe = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SGEgTG9uZyBCYXk=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_71a5d5ee9b784d65b7b8ba33f6e01add.setContent(i_frame_2586c6b1ad6c824a2221ae26de0e6cbe);
#
#
#
#         marker_d31e75d6e8f4fc0694e7654062b4414e.bindPopup(popup_71a5d5ee9b784d65b7b8ba33f6e01add)
#         ;
#
#
#
#
#             var marker_08e0b9edbf4510fded8300fafca8555e = L.marker(
#                 [15.88030077, 108.3380075],
#                 {&quot;c&quot;: &quot;Hoi An Ancient Town&quot;}
#             ).addTo(map_686021c6b18ae445d56ac345d7f4187a);
#
#
#         var popup_eef001afa62ca241b258d7c479a30366 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_2f02f82dabfa2580c076782cf6f44e2c = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBBdHRyYWN0aW9uIE5hbWU6SG9pIEFuIEFuY2llbnQgVG93bg==&quot; style=&quot;position:abs

# %%
print("Total travel time: ", total_time, "+ 9 * 5", "/ 100")
print("Total cost: ", total_cost, "/ 200")
# Out:
# Total travel time:  47.0 + 9 * 5 / 100
# Total cost:  186.5 / 200
